# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import sys
import os

from DFT_KIT.core import general_tool
from DFT_KIT.core import calculator,job
from DFT_KIT.calculator import Pseudo_Potential

# %%
os.chdir('/Users/shiangfang/Shiang DrobBox/Dropbox/Physics Research/Tim Kaxiras Group/temp/ld1x/')

dft_job=job.job(subdir=False,job_manager_mode=False,write_post_process=False)
dft_calc=Pseudo_Potential.calculator_LD1X(True,dft_job,None)

pswfc=dft_calc.post_process_read_pswfc()

# %%
plt.plot(pswfc[:,0],pswfc[:,1],pswfc[:,0],pswfc[:,6])
plt.xlim([0,10])
plt.title('5S')

# %%
plt.plot(pswfc[:,0],pswfc[:,2],pswfc[:,0],pswfc[:,7])
plt.xlim([0,10])
plt.title('5P')

# %%
plt.plot(pswfc[:,0],pswfc[:,3],pswfc[:,0],pswfc[:,8])
plt.xlim([0,10])
plt.title('5P')

# %%
plt.plot(pswfc[:,0],pswfc[:,4],pswfc[:,0],pswfc[:,9])
plt.xlim([0,10])
plt.title('5P')

# %%
plt.plot(pswfc[:,0],pswfc[:,5],pswfc[:,0],pswfc[:,10])
plt.xlim([0,10])
plt.title('5P')

# %%
pslog=dft_calc.post_process_read_pswfc('ld1.dlog')
pslogpp=dft_calc.post_process_read_pswfc('ld1ps.dlog')

# %%
plt.plot(pslog[:,0],pslog[:,1],pslogpp[:,0],pslogpp[:,1])


plt.ylim([-10,10])
plt.xlim([-15,15])
# Out:
# (-15, 15)

# %%
plt.plot(pslog[:,0],pslog[:,2],pslogpp[:,0],pslogpp[:,2])


plt.ylim([-10,10])
plt.xlim([-15,15])
# Out:
# (-15, 15)

# %%
plt.plot(pslog[:,0],pslog[:,3],pslogpp[:,0],pslogpp[:,3])


plt.ylim([-10,10])
plt.xlim([-15,15])
# Out:
# (-15, 15)

# %%
plt.plot(pslog[:,0],pslog[:,4],pslogpp[:,0],pslogpp[:,4])


plt.ylim([-10,10])
plt.xlim([-15,15])
# Out:
# (-15, 15)
