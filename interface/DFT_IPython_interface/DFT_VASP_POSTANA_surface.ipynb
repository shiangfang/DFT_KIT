# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import sys
import os

sys.path.append('/Users/shiangfang/Shiang DrobBox/Dropbox/Physics Research/Tim Kaxiras Group/DFT VASP/DFT_tools')
import DFT_input
import DFT_postana
import DFT_output
import DFT_job_submission
import general_tool

# %%
#Load the postana or do the postana here
xmlfilename='../bi_surface/bi_h_surface_soi_kslice.xml'
#xmlfilename='../bi_bulk/vasp_pbe_nod_0.xml'

vaspana=DFT_postana.DFT_post_ana()
vaspana.postana_mode=1
vaspana.vasp_postana_xml({}, xmlfilename)

# %%
#get and print out variables
variables=['VASPversion','VASPsubversion']


for var_ in variables:
    print('VASP[ '+var_+' ] = ' +str(vaspana.vasp_vars[var_]))
    
print(vaspana.vasp_vars['EFermi'])
print(float('10'))
# Out:
# VASP[ VASPversion ] = 5.3.5
# VASP[ VASPsubversion ] = 31Mar14 (build May 13 2014 21:22:14) complex                          serial
#       1.88562601
# 10.0

# %%
#preparation for band plot
sub_num=int(vaspana.vasp_vars['kpt_gen_div'])
tot_num=len(vaspana.vasp_band_kpoints)
kpt_ordering=general_tool.segments(sub_num,tot_num/sub_num)
#kpt_ordering.swap_groups(0,1)
#kpt_ordering.invert_group(0)
#kpt_ordering.print_ordering()

# %%
#band plot
band_energies=general_tool.convert_array_2d(vaspana.vasp_band_energies)
plt.plot(band_energies[kpt_ordering.get_ordering(),:])
plt.ylim([float(vaspana.vasp_vars['EFermi'])-0.2,float(vaspana.vasp_vars['EFermi'])+0.2])
#plt.ylim([-20,10])
#plt.xlim([0,100])
#plt.xlim([0,49])
#plt.xlim([0,100])
plt.plot(float(vaspana.vasp_vars['EFermi'])*np.ones(100))

#no d electrons
#print('Without D-electrons')
#print((band_energies[49,9]-band_energies[99,10])*1000)
#print((band_energies[49,9]))
#print((band_energies[99,10]))

print('With D-electrons')
#with d electrons
#print((band_energies[49,29]-band_energies[99,30])*1000)
#print((band_energies[49,29]))
#print((band_energies[99,30]))
# Out:
# With D-electrons

# %%
#band plot
band_energies=general_tool.convert_array_2d(vaspana.vasp_band_energies)
plt.plot(band_energies[kpt_ordering.get_ordering(),:])
plt.ylim([1.5,2.5])
#plt.xlim([50,100])
plt.xlim([0,24])
#plt.plot(5.67898124 *np.ones(100))
# Out:
# (0, 24)

# %%
print(vaspana.vasp_band_energies[10])
# Out:
# ['-10.8323', '-10.8316', '-10.7481', '-10.7480', '-10.7211', '-10.7210', '-10.6749', '-10.6746', '-10.6127', '-10.6124', '-10.5367', '-10.5364', '-10.4498', '-10.4494', '-10.3522', '-10.3518', '-10.2459', '-10.2454', '-10.1330', '-10.1325', '-10.0174', '-10.0170', '-9.9052', '-9.9048', '-9.8014', '-9.8011', '-9.7118', '-9.7116', '-9.6419', '-9.6418', '-7.9695', '-7.9687', '-7.8798', '-7.8794', '-7.7872', '-7.7864', '-7.6619', '-7.6608', '-7.5176', '-7.5162', '-7.3635', '-7.3618', '-7.2079', '-7.2059', '-7.0557', '-7.0534', '-6.9108', '-6.9085', '-6.7766', '-6.7744', '-6.6563', '-6.6544', '-6.5538', '-6.5522', '-6.4688', '-6.4676', '-6.4007', '-6.4000', '-6.3496', '-6.3493', '-2.1556', '-1.9678', '-1.9201', '-1.8888', '-1.8753', '-1.8435', '-1.8185', '-1.7724', '-1.7413', '-1.6895', '-1.6521', '-1.6278', '-1.5686', '-1.5582', '-1.4824', '-1.4677', '-1.3959', '-1.3795', '-1.3032', '-1.2819', '-1.1976', '-1.1693', '-1.0811', '-1.0446', '-0.9611', '-0.9159', '-0.8460', '-0.7948', '-0.7599', '-0.7488', '-0.7437', '-0.6971', '-0.6916', '-0.6882', '-0.6681', '-0.6094', '-0.5880', '-0.4958', '-0.4684', '-0.3623', '-0.3284', '-0.2155', '-0.1742', '-0.0657', '-0.0121', '0.0503', '0.1312', '0.1509', '0.2689', '0.3004', '0.3374', '0.3456', '0.3849', '0.3884', '0.4207', '0.4325', '0.4514', '0.4735', '0.5269', '0.5355', '0.5650', '0.6023', '0.6440', '0.6465', '0.6957', '0.7254', '0.7571', '0.7625', '0.8008', '0.8125', '0.8554', '0.8732', '0.9231', '0.9285', '0.9865', '0.9984', '1.0811', '1.0885', '1.1874', '1.2253', '1.2457', '1.2637', '1.3272', '1.3803', '1.4624', '1.5060', '1.5792', '1.6019', '1.6734', '1.6824', '1.9001', '2.0266', '2.2845', '2.3328', '2.3856', '2.4202', '2.4579', '2.4892', '2.5152', '2.5282', '2.5711', '2.5877', '2.6687', '2.7017', '2.8195', '2.8543', '2.9999', '3.0236', '3.1793', '3.1872', '3.2085', '3.2129', '3.3394', '3.3418', '3.4105', '3.4159', '3.5387', '3.5444', '3.6433', '3.6665', '3.7672', '3.8217']

# %%
#DOS plot
conv_dos=general_tool.convert_array_2d(vaspana.vasp_dos)
conv_dos[1,0]
plt.figure(figsize=[12,4])
plt.subplot(1,2,1)
plt.plot(conv_dos[:,0],conv_dos[:,1])
plt.xlim([-20,20])
plt.ylim([-1,6])
plt.subplot(1,2,2)
plt.plot(conv_dos[:,0],conv_dos[:,2])
print(vaspana.vasp_vars['EFermi'])
# Out:
#       1.88562601

# %%
#calculation information
scdata=vaspana.vasp_postana_calculation('SC_Etotsig0',True,-1)
plt.plot(scdata)

# %%
#each calculation/scsteps

# %%
conv_dos[1,0]
# Out:
# -20.6966
