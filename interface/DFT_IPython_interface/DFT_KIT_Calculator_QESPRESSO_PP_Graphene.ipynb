# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import sys
import os

import xml.etree.ElementTree as ET
from DFT_KIT.core import job
from DFT_KIT.calculator import QESPRESSO
from DFT_KIT.core import physics

# %%
os.chdir('/Users/shiangfang/Desktop/Temp/mos2/mos2.vaspwan/')

dft_job=job.job(False,False,False)
dft_calc=QESPRESSO.calculator_QESPRESSO(True,dft_job,None,None)
dft_job.sys_info['qes_prefix']='graphene'
dft_calc.post_process()
# Out:
# DFT_KIT(ERROR):QESPRESSO: pp-no out file

# %%
plt.plot(physics.hartree*np.transpose(dft_calc.qes_vars['eigenvalues']))
#plt.ylim([4,10])
#plt.ylim([-90,-50])
# Out:
# [<matplotlib.lines.Line2D at 0x1082c3b50>,
#  <matplotlib.lines.Line2D at 0x1082c3850>,
#  <matplotlib.lines.Line2D at 0x1082c34d0>,
#  <matplotlib.lines.Line2D at 0x1082717d0>,
#  <matplotlib.lines.Line2D at 0x108271b90>,
#  <matplotlib.lines.Line2D at 0x108271c90>,
#  <matplotlib.lines.Line2D at 0x108271f90>,
#  <matplotlib.lines.Line2D at 0x107c7db10>,
#  <matplotlib.lines.Line2D at 0x108271310>,
#  <matplotlib.lines.Line2D at 0x108271150>,
#  <matplotlib.lines.Line2D at 0x1082cce10>,
#  <matplotlib.lines.Line2D at 0x1082cc550>,
#  <matplotlib.lines.Line2D at 0x1082cc710>,
#  <matplotlib.lines.Line2D at 0x1082ccc50>,
#  <matplotlib.lines.Line2D at 0x108271110>,
#  <matplotlib.lines.Line2D at 0x1082cca90>]
