# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import sys
import os

import xml.etree.ElementTree as ET

from DFT_KIT.core import physics

# %%
os.chdir('/Users/shiangfang/Shiang DrobBox/Dropbox/Physics Research/Tim Kaxiras Group/DFT_KIT/temp/sb_slab_pot')

data=np.loadtxt('sb.avg.out',skiprows=24)

print(data)
# Out:
# [[  0.00000000e+00   5.79440694e-01   5.79432999e-01]
#  [  9.89472470e-02   5.79426673e-01   5.79431803e-01]
#  [  1.97894494e-01   5.79431674e-01   5.79430371e-01]
#  ...,
#  [  1.48124029e+02   5.79442047e-01   5.79436741e-01]
#  [  1.48222976e+02   5.79457580e-01   5.79435391e-01]
#  [  1.48321923e+02   5.79457703e-01   5.79434135e-01]]

# %%
plt.plot(data[:,0],data[:,1])
print(data[:,0].size)
plt.xlim([0,148])
plt.xlabel('Z position (Bohr)')
plt.ylabel('Energy')

plt.xlim([10,40])
# Out:
# 1500
# (10, 40)

# %%
plt.plot(data[:,0],data[:,2])
plt.ylim([-.46,-.4])
# Out:
# (-0.46, -0.4)

# %%
os.chdir('/Users/shiangfang/Shiang DrobBox/Dropbox/Physics Research/Tim Kaxiras Group/DFT_KIT/temp/sb_slab_pot')

data=np.loadtxt('bi.avg.out',skiprows=24)

print(data)
# Out:
# [[  0.00000000e+00   4.93297040e-01   4.93257388e-01]
#  [  1.04034165e-01   4.93285871e-01   4.93256742e-01]
#  [  2.08068330e-01   4.93238242e-01   4.93256112e-01]
#  ...,
#  [  1.55739145e+02   4.93256954e-01   4.93259453e-01]
#  [  1.55843180e+02   4.93227106e-01   4.93258942e-01]
#  [  1.55947214e+02   4.93256126e-01   4.93258186e-01]]

# %%
plt.plot(data[:,0],data[:,1])
print(data[:,0].size)
plt.xlim([0,148])
plt.xlabel('Z position (Bohr)')
plt.ylabel('Energy')

plt.xlim([10,50])
# Out:
# 1500
# (10, 50)

# %%
plt.plot(data[:,0],data[:,2])
plt.ylim([-.3,-.24])
#plt.ylim([0.21,0.3])
# Out:
# (-0.3, -0.24)
