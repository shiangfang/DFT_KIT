# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import sys
import os

import xml.etree.ElementTree as ET

from DFT_KIT.core import physics

# %%
os.chdir('/Users/shiangfang/Shiang DrobBox/Dropbox/Physics Research/Tim Kaxiras Group/DFT_KIT/temp/sb_slab_pot')

datasb=np.loadtxt('sb.avg.out',skiprows=24)

print(data)
# Out:
# [[  0.00000000e+00   0.00000000e+00   0.00000000e+00]
#  [  9.89472470e-02   0.00000000e+00   0.00000000e+00]
#  [  1.97894494e-01   0.00000000e+00   0.00000000e+00]
#  ...,
#  [  1.48124029e+02   0.00000000e+00   0.00000000e+00]
#  [  1.48222976e+02   0.00000000e+00   0.00000000e+00]
#  [  1.48321923e+02   0.00000000e+00   0.00000000e+00]]

# %%
plt.plot(datasb[:,0],datasb[:,1])
print(datasb[:,0].size)
plt.xlim([0,148])
plt.xlabel('Z position (Bohr)')
plt.ylabel('Energy')

plt.xlim([10,40])
# Out:
# 1500
# (10, 40)

# %%
plt.plot(datasb[:,0],datasb[:,1])
plt.ylim([-.485,-.465])
# Out:
# (-0.485, -0.465)

# %%
os.chdir('/Users/shiangfang/Shiang DrobBox/Dropbox/Physics Research/Tim Kaxiras Group/DFT_KIT/temp/sb_slab_pot')

databi=np.loadtxt('bi.avg.out',skiprows=24)

print(data)
# Out:
# [[  0.00000000e+00   0.00000000e+00   0.00000000e+00]
#  [  9.89472470e-02   0.00000000e+00   0.00000000e+00]
#  [  1.97894494e-01   0.00000000e+00   0.00000000e+00]
#  ...,
#  [  1.48124029e+02   0.00000000e+00   0.00000000e+00]
#  [  1.48222976e+02   0.00000000e+00   0.00000000e+00]
#  [  1.48321923e+02   0.00000000e+00   0.00000000e+00]]

# %%
plt.plot(databi[:,0],databi[:,1])
print(databi[:,0].size)
plt.xlim([0,148])
plt.xlabel('Z position (Bohr)')
plt.ylabel('Energy')

plt.xlim([10,50])
# Out:
# 1500
# (10, 50)

# %%
plt.plot(databi[:,0],databi[:,1])
plt.ylim([-.33,-.31])
#plt.ylim([0.21,0.3])
# Out:
# (-0.33, -0.31)

# %%
os.chdir('/Users/shiangfang/Shiang DrobBox/Dropbox/Physics Research/Tim Kaxiras Group/DFT_KIT/temp/sb_slab_pot')

dataden=np.loadtxt('sb.avg.den.out',skiprows=24)

print(data)
# Out:
# [[  0.00000000e+00   0.00000000e+00   0.00000000e+00]
#  [  9.89472470e-02   0.00000000e+00   0.00000000e+00]
#  [  1.97894494e-01   0.00000000e+00   0.00000000e+00]
#  ...,
#  [  1.48124029e+02   0.00000000e+00   0.00000000e+00]
#  [  1.48222976e+02   0.00000000e+00   0.00000000e+00]
#  [  1.48321923e+02   0.00000000e+00   0.00000000e+00]]

# %%
plt.plot(dataden[:,0],dataden[:,1])
print(dataden[:,0].size)
plt.xlim([0,148])
plt.xlabel('Z position (Bohr)')
plt.ylabel('Electron Density')

#plt.xlim([10,50])
# Out:
# 1500
