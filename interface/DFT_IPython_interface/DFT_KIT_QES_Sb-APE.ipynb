# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import sys
import os

import xml.etree.ElementTree as ET
from DFT_KIT.core import job
from DFT_KIT.calculator import QESPRESSO
from DFT_KIT.core import physics

# %%
os.chdir('/Users/shiangfang/Shiang DrobBox/Dropbox/Physics Research/Tim Kaxiras Group/temp/new_biband/')

dft_job=job.job(False,False,False)
dft_calc=QESPRESSO.calculator_QESPRESSO(True,dft_job,None,None)
dft_job.sys_info['qes_prefix']='bi_sb_vca_alloy2'
dft_calc.post_process()
# Out:
# DFT_KIT(ERROR):QESPRESSO: pp-no out file

# %%
plt.plot(physics.hartree*np.transpose(dft_calc.qes_vars['eigenvalues']))
#plt.ylim([0,10])
#plt.ylim([-90,-50])
# Out:
# [<matplotlib.lines.Line2D at 0x107b2b190>,
#  <matplotlib.lines.Line2D at 0x107b2b410>,
#  <matplotlib.lines.Line2D at 0x107b2b650>,
#  <matplotlib.lines.Line2D at 0x107b2b810>,
#  <matplotlib.lines.Line2D at 0x107b2b9d0>,
#  <matplotlib.lines.Line2D at 0x107b2bb90>,
#  <matplotlib.lines.Line2D at 0x107b2bd50>,
#  <matplotlib.lines.Line2D at 0x107b0bb90>,
#  <matplotlib.lines.Line2D at 0x107b2d110>,
#  <matplotlib.lines.Line2D at 0x107b2d2d0>,
#  <matplotlib.lines.Line2D at 0x107b2d490>,
#  <matplotlib.lines.Line2D at 0x107b2d650>,
#  <matplotlib.lines.Line2D at 0x107b2d810>,
#  <matplotlib.lines.Line2D at 0x107b2d9d0>,
#  <matplotlib.lines.Line2D at 0x107b2bf50>,
#  <matplotlib.lines.Line2D at 0x107b2dd50>,
#  <matplotlib.lines.Line2D at 0x107b2df10>,
#  <matplotlib.lines.Line2D at 0x107b2e110>,
#  <matplotlib.lines.Line2D at 0x107b2e2d0>,
#  <matplotlib.lines.Line2D at 0x107b2e490>,
#  <matplotlib.lines.Line2D at 0x107b2e650>,
#  <matplotlib.lines.Line2D at 0x107b2dbd0>,
#  <matplotlib.lines.Line2D at 0x107b17d90>,
#  <matplotlib.lines.Line2D at 0x107b17610>,
#  <matplotlib.lines.Line2D at 0x107b173d0>]
