# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import sys
import os

import xml.etree.ElementTree as ET
from DFT_KIT.core import job
from DFT_KIT.calculator import QESPRESSO
from DFT_KIT.core import physics

# %%
os.chdir('/Users/shiangfang/Shiang DrobBox/Dropbox/Physics Research/Tim Kaxiras Group/temp/new_biband/')

dft_job=job.job(False,False,False)
dft_calc=QESPRESSO.calculator_QESPRESSO(True,dft_job,None,None)
dft_job.sys_info['qes_prefix']='bi_prefix'
dft_calc.post_process()
# Out:
# DFT_KIT(ERROR):QESPRESSO: pp-no out file

# %%
plt.plot(physics.hartree*np.transpose(dft_calc.qes_vars['eigenvalues']))
#plt.ylim([4,5.5])
#plt.ylim([-90,-50])
# Out:
# [<matplotlib.lines.Line2D at 0x107c6ee10>,
#  <matplotlib.lines.Line2D at 0x107c720d0>,
#  <matplotlib.lines.Line2D at 0x107c72310>,
#  <matplotlib.lines.Line2D at 0x107c724d0>,
#  <matplotlib.lines.Line2D at 0x107c72690>,
#  <matplotlib.lines.Line2D at 0x107c72850>,
#  <matplotlib.lines.Line2D at 0x107c72a10>,
#  <matplotlib.lines.Line2D at 0x107c4b450>,
#  <matplotlib.lines.Line2D at 0x107c72d90>,
#  <matplotlib.lines.Line2D at 0x107c72f50>,
#  <matplotlib.lines.Line2D at 0x107c73150>,
#  <matplotlib.lines.Line2D at 0x107c73310>,
#  <matplotlib.lines.Line2D at 0x107c734d0>,
#  <matplotlib.lines.Line2D at 0x107c73690>,
#  <matplotlib.lines.Line2D at 0x107c72c10>,
#  <matplotlib.lines.Line2D at 0x107c73a10>,
#  <matplotlib.lines.Line2D at 0x107c73bd0>,
#  <matplotlib.lines.Line2D at 0x107c73d90>,
#  <matplotlib.lines.Line2D at 0x107c73f50>,
#  <matplotlib.lines.Line2D at 0x107c76150>,
#  <matplotlib.lines.Line2D at 0x107c76310>,
#  <matplotlib.lines.Line2D at 0x107c73890>,
#  <matplotlib.lines.Line2D at 0x107c76690>,
#  <matplotlib.lines.Line2D at 0x107c76850>,
#  <matplotlib.lines.Line2D at 0x107c76a10>]
