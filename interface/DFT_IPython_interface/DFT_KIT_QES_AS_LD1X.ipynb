# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import sys
import os

import xml.etree.ElementTree as ET
from DFT_KIT.core import job
from DFT_KIT.calculator import QESPRESSO
from DFT_KIT.core import physics

# %%
os.chdir('/Users/shiangfang/Shiang DrobBox/Dropbox/Physics Research/Tim Kaxiras Group/temp/new_biband/')

dft_job=job.job(False,False,False)
dft_calc=QESPRESSO.calculator_QESPRESSO(True,dft_job,None,None)
dft_job.sys_info['qes_prefix']='as_prefix'
dft_calc.post_process()
# Out:
# DFT_KIT(ERROR):QESPRESSO: pp-no out file

# %%
plt.plot(physics.hartree*np.transpose(dft_calc.qes_vars['eigenvalues']))
#plt.ylim([5,10.5])
#plt.ylim([-90,-50])
# Out:
# [<matplotlib.lines.Line2D at 0x107d0bd10>,
#  <matplotlib.lines.Line2D at 0x107d0bf90>,
#  <matplotlib.lines.Line2D at 0x107d0f210>,
#  <matplotlib.lines.Line2D at 0x107d0f3d0>,
#  <matplotlib.lines.Line2D at 0x107d0f590>,
#  <matplotlib.lines.Line2D at 0x107d0f750>,
#  <matplotlib.lines.Line2D at 0x107d0f910>,
#  <matplotlib.lines.Line2D at 0x1079ec350>,
#  <matplotlib.lines.Line2D at 0x107d0fc90>,
#  <matplotlib.lines.Line2D at 0x107d0fe50>,
#  <matplotlib.lines.Line2D at 0x107d11050>,
#  <matplotlib.lines.Line2D at 0x107d11210>,
#  <matplotlib.lines.Line2D at 0x107d113d0>,
#  <matplotlib.lines.Line2D at 0x107d11590>,
#  <matplotlib.lines.Line2D at 0x107d0fb10>,
#  <matplotlib.lines.Line2D at 0x107d11910>,
#  <matplotlib.lines.Line2D at 0x107d11ad0>,
#  <matplotlib.lines.Line2D at 0x107d11c90>,
#  <matplotlib.lines.Line2D at 0x107d11e50>,
#  <matplotlib.lines.Line2D at 0x107d12050>,
#  <matplotlib.lines.Line2D at 0x107d12210>,
#  <matplotlib.lines.Line2D at 0x107d11790>,
#  <matplotlib.lines.Line2D at 0x107d12590>,
#  <matplotlib.lines.Line2D at 0x107d12750>,
#  <matplotlib.lines.Line2D at 0x107d12910>]
