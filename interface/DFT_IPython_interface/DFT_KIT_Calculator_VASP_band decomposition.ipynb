# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import sys
import os

import xml.etree.ElementTree as ET

from DFT_KIT.core import job
from DFT_KIT.calculator import VASP


print(os.getcwd())
# Out:
# /Users/shiangfang/Shiang DrobBox/Dropbox/Physics Research/Tim Kaxiras Group/DFT_KIT/interface/DFT_IPython_interface

# %%
os.chdir('/Users/shiangfang/Desktop/Temp/mos2-dec')

test_job=job.job(False,False,False)
test_calc=VASP.calculator_VASP(True,test_job,None,None)
test_calc.post_process()

print(test_calc.output['fermi_energy'])
# Out:
# -2.391653

# %%
plt.plot(test_calc.vasp_vars['KPTS_BAND'])

print(len(test_calc.vasp_vars['KPTS_BAND'][0]))

#plt.ylim([4.6,6.6])
#plt.xlim([0,50])
#plt.ylim([0,7])
# Out:
# 13

# %%
# plot the decomposition

    
orb_a=2
orb_l=0
num_kpts=len(test_calc.vasp_vars['KPTS_BAND'])
num_bands=len(test_calc.vasp_vars['KPTS_BAND'][0])

for indk in range(0,num_kpts):
    for indb in range(0,num_bands):
        pos_x=indk*10.0/num_kpts
        pos_y=test_calc.vasp_vars['KPTS_BAND'][indk][indb]
        pos_r=test_calc.vasp_vars['PROJECT_BAND'][0][indk][indb][orb_a][orb_l]
        circle = plt.Circle((pos_x,pos_y), 2.0*pos_r, fc='r')
        plt.gca().add_patch(circle)

plt.xlim([0,10])
#plt.xlim([0,5])
plt.ylim([-18,-2])
plt.show()

# %%
plt.figure(figsize=(12,9))
plt.axes()

circle = plt.Circle((ind1,ind2), 0.2, fc='y')
plt.gca().add_patch(circle)

line = plt.Line2D((ind1, ind1+1), (ind2,ind2), lw=3.0)
                plt.gca().add_line(line)


N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N))**2 # 0 to 15 point radiuses

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N))**2 # 0 to 15 point radiuses

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()
