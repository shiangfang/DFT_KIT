# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import sys
import os

import xml.etree.ElementTree as ET
from DFT_KIT.core import job
from DFT_KIT.calculator import QESPRESSO
from DFT_KIT.core import physics

# %%
os.chdir('/Users/shiangfang/Shiang DrobBox/Dropbox/Physics Research/Tim Kaxiras Group/temp/new_biband/')

dft_job=job.job(False,False,False)
dft_calc=QESPRESSO.calculator_QESPRESSO(True,dft_job,None,None)
dft_job.sys_info['qes_prefix']='sb_prefix'
dft_calc.post_process()
# Out:
# DFT_KIT(ERROR):QESPRESSO: pp-no out file

# %%
plt.plot(physics.hartree*np.transpose(dft_calc.qes_vars['eigenvalues']))
#plt.ylim([4,5.5])
#plt.ylim([-90,-50])
# Out:
# [<matplotlib.lines.Line2D at 0x107ca5110>,
#  <matplotlib.lines.Line2D at 0x107ca54d0>,
#  <matplotlib.lines.Line2D at 0x107ca5fd0>,
#  <matplotlib.lines.Line2D at 0x107ca5890>,
#  <matplotlib.lines.Line2D at 0x107ca5610>,
#  <matplotlib.lines.Line2D at 0x107ca5350>,
#  <matplotlib.lines.Line2D at 0x107ca5d10>,
#  <matplotlib.lines.Line2D at 0x107cad510>,
#  <matplotlib.lines.Line2D at 0x107c634d0>,
#  <matplotlib.lines.Line2D at 0x107c56e50>,
#  <matplotlib.lines.Line2D at 0x107c3efd0>,
#  <matplotlib.lines.Line2D at 0x107c3e390>,
#  <matplotlib.lines.Line2D at 0x107ca32d0>,
#  <matplotlib.lines.Line2D at 0x107ca3190>,
#  <matplotlib.lines.Line2D at 0x107ca5790>,
#  <matplotlib.lines.Line2D at 0x107ca3650>,
#  <matplotlib.lines.Line2D at 0x107ca3890>,
#  <matplotlib.lines.Line2D at 0x107ca3a10>,
#  <matplotlib.lines.Line2D at 0x107ca3d50>,
#  <matplotlib.lines.Line2D at 0x107ca3f10>,
#  <matplotlib.lines.Line2D at 0x107cab410>,
#  <matplotlib.lines.Line2D at 0x107ca3450>,
#  <matplotlib.lines.Line2D at 0x107cab5d0>,
#  <matplotlib.lines.Line2D at 0x107cab810>,
#  <matplotlib.lines.Line2D at 0x107cabb90>]
