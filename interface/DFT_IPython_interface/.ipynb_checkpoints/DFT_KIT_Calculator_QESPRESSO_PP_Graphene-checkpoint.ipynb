# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import sys
import os

import xml.etree.ElementTree as ET
from DFT_KIT.core import job
from DFT_KIT.calculator import QESPRESSO
from DFT_KIT.core import physics

# %%
os.chdir('/Users/shiangfang/Desktop/Temp/mos2/mos2.vaspwan/')

dft_job=job.job(False,False,False)
dft_calc=QESPRESSO.calculator_QESPRESSO(True,dft_job,None,None)
dft_job.sys_info['qes_prefix']='bi_prefix'
dft_calc.post_process()
# Out:
# DFT_KIT(ERROR):QESPRESSO: pp-no out file

# %%
plt.plot(physics.hartree*np.transpose(dft_calc.qes_vars['eigenvalues']))
#plt.ylim([5,10])
#plt.ylim([-90,-50])
# Out:
# [<matplotlib.lines.Line2D at 0x107aaa290>,
#  <matplotlib.lines.Line2D at 0x107aaa510>,
#  <matplotlib.lines.Line2D at 0x107aaa750>,
#  <matplotlib.lines.Line2D at 0x107aaa910>,
#  <matplotlib.lines.Line2D at 0x107aaaad0>,
#  <matplotlib.lines.Line2D at 0x107aaac90>,
#  <matplotlib.lines.Line2D at 0x107aaae50>,
#  <matplotlib.lines.Line2D at 0x107a8d250>,
#  <matplotlib.lines.Line2D at 0x107aab210>,
#  <matplotlib.lines.Line2D at 0x107aab3d0>,
#  <matplotlib.lines.Line2D at 0x107aab590>,
#  <matplotlib.lines.Line2D at 0x107aab750>,
#  <matplotlib.lines.Line2D at 0x107aab910>,
#  <matplotlib.lines.Line2D at 0x107aabad0>,
#  <matplotlib.lines.Line2D at 0x107aabc90>,
#  <matplotlib.lines.Line2D at 0x107aabe50>,
#  <matplotlib.lines.Line2D at 0x107aad050>,
#  <matplotlib.lines.Line2D at 0x107aad210>,
#  <matplotlib.lines.Line2D at 0x107aad3d0>,
#  <matplotlib.lines.Line2D at 0x107aad590>]
