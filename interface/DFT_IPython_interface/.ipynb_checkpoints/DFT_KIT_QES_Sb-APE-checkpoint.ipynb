# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import sys
import os

import xml.etree.ElementTree as ET
from DFT_KIT.core import job
from DFT_KIT.calculator import QESPRESSO
from DFT_KIT.core import physics

# %%
os.chdir('/Users/shiangfang/Shiang DrobBox/Dropbox/Physics Research/Tim Kaxiras Group/temp/new_biband/')

dft_job=job.job(False,False,False)
dft_calc=QESPRESSO.calculator_QESPRESSO(True,dft_job,None,None)
dft_job.sys_info['qes_prefix']='bi_sb_vca_alloy2'
dft_calc.post_process()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-2-dd69a51223e5> in <module>()
#       5 dft_calc=QESPRESSO.calculator_QESPRESSO(True,dft_job,None,None)
#       6 dft_job.sys_info['qes_prefix']='bi_sb_vca_alloy2'
# ----> 7 dft_calc.post_process()
#       8
#       9
#
# /Users/shiangfang/Shiang DrobBox/Dropbox/Physics Research/Tim Kaxiras Group/DFT_KIT/calculator/QESPRESSO.pyc in post_process(self)
#     242         self.qes_vars['ewald_energy']=0.0
#     243
# --> 244         self.qespresso_post_process_xml(self.dft_job.sys_info['qes_prefix']+'.save/' ,'data-file.xml')
#     245         if os.path.isfile(self.dft_job.sys_info['qes_fname']+'.pwx.out'):
#     246             self.qespresso_post_process_outfile(self.dft_job.sys_info['qes_fname']+'.pwx.out')
#
# /Users/shiangfang/Shiang DrobBox/Dropbox/Physics Research/Tim Kaxiras Group/DFT_KIT/calculator/QESPRESSO.pyc in qespresso_post_process_xml(self, xmldir, xmlfile)
#     327
#     328     def qespresso_post_process_xml(self,xmldir,xmlfile='data-file.xml'):
# --> 329         tree = ET.parse(xmldir+xmlfile)
#     330         root = tree.getroot()
#     331
#
# /Applications/Anaconda/anaconda/python.app/Contents/lib/python2.7/xml/etree/ElementTree.pyc in parse(source, parser)
#    1180 def parse(source, parser=None):
#    1181     tree = ElementTree()
# -> 1182     tree.parse(source, parser)
#    1183     return tree
#    1184
#
# /Applications/Anaconda/anaconda/python.app/Contents/lib/python2.7/xml/etree/ElementTree.pyc in parse(self, source, parser)
#     645         close_source = False
#     646         if not hasattr(source, "read"):
# --> 647             source = open(source, "rb")
#     648             close_source = True
#     649         try:
#
# IOError: [Errno 2] No such file or directory: 'bi_sb_vca_alloy2.save/data-file.xml'

# %%
plt.plot(physics.hartree*np.transpose(dft_calc.qes_vars['eigenvalues']))
#plt.ylim([0,10])
#plt.ylim([-90,-50])
# Out:
# (0, 10)
