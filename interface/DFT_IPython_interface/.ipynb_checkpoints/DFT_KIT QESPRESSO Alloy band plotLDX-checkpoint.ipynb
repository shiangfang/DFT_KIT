# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import sys
import os

import xml.etree.ElementTree as ET

from DFT_KIT.core import physics

#sys.path.append('/Users/shiangfang/Shiang DrobBox/Dropbox/Physics Research/Tim Kaxiras Group/DFT VASP/DFT_tools')

# %%
name_prefix='../../temp/bi_sb_alloy/final_data_LDX2'
all_xs=np.linspace(0,1,21)
all_ones=np.linspace(1,1,21)
f_=open(name_prefix,'rb')
fermi_level=pickle.load(f_)
fermi_level=np.array(fermi_level)*physics.hartree
all_bands=pickle.load(f_)
all_bands=np.array(all_bands)*physics.hartree
fermi_level2=pickle.load(f_)
fermi_level2=np.array(fermi_level2)*physics.hartree
f_.close()
print(all_bands[5,1,1])

plt.plot(np.transpose(all_bands[20]))
#plt.ylim([5,10])
# Out:
# -4.64831932503
# [<matplotlib.lines.Line2D at 0x108c8c390>,
#  <matplotlib.lines.Line2D at 0x108c8c610>,
#  <matplotlib.lines.Line2D at 0x108c8c850>,
#  <matplotlib.lines.Line2D at 0x108c8ca10>,
#  <matplotlib.lines.Line2D at 0x108c8cbd0>,
#  <matplotlib.lines.Line2D at 0x108c8cd90>,
#  <matplotlib.lines.Line2D at 0x108c8cf50>,
#  <matplotlib.lines.Line2D at 0x108c71dd0>,
#  <matplotlib.lines.Line2D at 0x108c92310>,
#  <matplotlib.lines.Line2D at 0x108c924d0>,
#  <matplotlib.lines.Line2D at 0x108c92690>,
#  <matplotlib.lines.Line2D at 0x108c92850>,
#  <matplotlib.lines.Line2D at 0x108c92a10>,
#  <matplotlib.lines.Line2D at 0x108c92bd0>,
#  <matplotlib.lines.Line2D at 0x108c92d90>,
#  <matplotlib.lines.Line2D at 0x108c92f50>,
#  <matplotlib.lines.Line2D at 0x108c94150>,
#  <matplotlib.lines.Line2D at 0x108c94310>]

# %%
plt.plot(all_xs,all_bands[:,8,0]-fermi_level2,all_xs,all_bands[:,11,0]-fermi_level2,all_xs,all_bands[:,8,101]-fermi_level2)

plt.plot(all_xs,all_bands[:,8,0]-fermi_level1,all_xs,all_bands[:,11,0]-fermi_level1,all_xs,all_bands[:,8,101]-fermi_level1)
# Out:
# [<matplotlib.lines.Line2D at 0x1089f7750>,
#  <matplotlib.lines.Line2D at 0x1089f79d0>,
#  <matplotlib.lines.Line2D at 0x1089fa0d0>]

# %%
plt.plot(all_xs,all_bands[:,4:15,0])
# Out:
# [<matplotlib.lines.Line2D at 0x10bfdcf90>,
#  <matplotlib.lines.Line2D at 0x10d101250>,
#  <matplotlib.lines.Line2D at 0x10d101490>,
#  <matplotlib.lines.Line2D at 0x10d101650>,
#  <matplotlib.lines.Line2D at 0x10d101810>,
#  <matplotlib.lines.Line2D at 0x10d1019d0>,
#  <matplotlib.lines.Line2D at 0x10d101b90>,
#  <matplotlib.lines.Line2D at 0x10bfc8650>,
#  <matplotlib.lines.Line2D at 0x10d101f10>,
#  <matplotlib.lines.Line2D at 0x10d104110>,
#  <matplotlib.lines.Line2D at 0x10d1042d0>]
