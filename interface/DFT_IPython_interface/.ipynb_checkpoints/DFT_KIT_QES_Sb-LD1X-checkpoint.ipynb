# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import sys
import os

import xml.etree.ElementTree as ET
from DFT_KIT.core import job
from DFT_KIT.calculator import QESPRESSO
from DFT_KIT.core import physics

# %%
os.chdir('/Users/shiangfang/Shiang DrobBox/Dropbox/Physics Research/Tim Kaxiras Group/temp/new_biband/')

dft_job=job.job(False,False,False)
dft_calc=QESPRESSO.calculator_QESPRESSO(True,dft_job,None,None)
dft_job.sys_info['qes_prefix']='sb_prefix'
dft_calc.post_process()
# Out:
# DFT_KIT(ERROR):QESPRESSO: pp-no out file

# %%
plt.plot(physics.hartree*np.transpose(dft_calc.qes_vars['eigenvalues']))
#plt.ylim([6,7])
#plt.ylim([-90,-50])
# Out:
# [<matplotlib.lines.Line2D at 0x108279350>,
#  <matplotlib.lines.Line2D at 0x1082d5110>,
#  <matplotlib.lines.Line2D at 0x1082d5350>,
#  <matplotlib.lines.Line2D at 0x1082d5510>,
#  <matplotlib.lines.Line2D at 0x1082d56d0>,
#  <matplotlib.lines.Line2D at 0x1082d5890>,
#  <matplotlib.lines.Line2D at 0x1082d5a50>,
#  <matplotlib.lines.Line2D at 0x107a96210>,
#  <matplotlib.lines.Line2D at 0x1082d5dd0>,
#  <matplotlib.lines.Line2D at 0x1082d5f90>,
#  <matplotlib.lines.Line2D at 0x1082ce190>,
#  <matplotlib.lines.Line2D at 0x1082ce350>,
#  <matplotlib.lines.Line2D at 0x1082ce510>,
#  <matplotlib.lines.Line2D at 0x1082ce6d0>,
#  <matplotlib.lines.Line2D at 0x1082d5c50>,
#  <matplotlib.lines.Line2D at 0x1082cea50>,
#  <matplotlib.lines.Line2D at 0x1082cec10>,
#  <matplotlib.lines.Line2D at 0x1082cedd0>,
#  <matplotlib.lines.Line2D at 0x1082cef90>,
#  <matplotlib.lines.Line2D at 0x1082d6190>,
#  <matplotlib.lines.Line2D at 0x1082d6350>,
#  <matplotlib.lines.Line2D at 0x1082ce8d0>,
#  <matplotlib.lines.Line2D at 0x1082d66d0>,
#  <matplotlib.lines.Line2D at 0x1082d6890>,
#  <matplotlib.lines.Line2D at 0x1082d6a50>]
