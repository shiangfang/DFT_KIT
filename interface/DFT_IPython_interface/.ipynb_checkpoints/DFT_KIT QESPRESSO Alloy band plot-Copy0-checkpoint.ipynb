# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import sys
import os

import xml.etree.ElementTree as ET

from DFT_KIT.core import physics
from DFT_KIT.interface import interface


#sys.path.append('/Users/shiangfang/Shiang DrobBox/Dropbox/Physics Research/Tim Kaxiras Group/DFT VASP/DFT_tools')

# %%
name_prefix='../../temp/bi_sb_alloy/final_data_ori2b'
all_xs=np.linspace(0,1,21)
all_ones=np.linspace(1,1,21)
f_=open(name_prefix,'rb')
fermi_level=pickle.load(f_)
fermi_level=np.array(fermi_level)*physics.hartree
all_bands=pickle.load(f_)
all_bands=np.array(all_bands)*physics.hartree
fermi_level2=pickle.load(f_)
fermi_level2=np.array(fermi_level2)*physics.hartree
f_.close()

plt.plot(np.transpose(all_bands[0]))
#plt.ylim([5,7])
# Out:
# [<matplotlib.lines.Line2D at 0x10bdc34d0>,
#  <matplotlib.lines.Line2D at 0x10bdc3750>,
#  <matplotlib.lines.Line2D at 0x10bdc3990>,
#  <matplotlib.lines.Line2D at 0x10bdc3b50>,
#  <matplotlib.lines.Line2D at 0x10bdc3d10>,
#  <matplotlib.lines.Line2D at 0x10bdc3ed0>,
#  <matplotlib.lines.Line2D at 0x10bdc60d0>,
#  <matplotlib.lines.Line2D at 0x10c124b50>,
#  <matplotlib.lines.Line2D at 0x10bdc6450>,
#  <matplotlib.lines.Line2D at 0x10bdc6610>,
#  <matplotlib.lines.Line2D at 0x10bdc67d0>,
#  <matplotlib.lines.Line2D at 0x10bdc6990>,
#  <matplotlib.lines.Line2D at 0x10bdc6b50>,
#  <matplotlib.lines.Line2D at 0x10bdc6d10>,
#  <matplotlib.lines.Line2D at 0x10bdc6ed0>,
#  <matplotlib.lines.Line2D at 0x10bde20d0>,
#  <matplotlib.lines.Line2D at 0x10bde2290>,
#  <matplotlib.lines.Line2D at 0x10bde2450>]

# %%
plt.plot(all_xs,all_bands[:,7,101]-fermi_level,all_xs,all_bands[:,8,0]-fermi_level,all_xs,all_bands[:,11,0]-fermi_level,all_xs,all_bands[:,8,101]-fermi_level)
#plt.plot(all_xs,all_bands[:,8,0]-fermi_level,all_xs,all_bands[:,10,0]-fermi_level)
#plt.plot(all_xs,all_bands[:,:,0],all_xs,all_bands[:,:,101])
#plt.ylim((-1,0.3))
# Out:
# [<matplotlib.lines.Line2D at 0x10c156250>,
#  <matplotlib.lines.Line2D at 0x10c1564d0>,
#  <matplotlib.lines.Line2D at 0x10c156b90>,
#  <matplotlib.lines.Line2D at 0x10c15b210>]

# %%
plt.plot(all_xs,all_bands[:,7,101]-fermi_level2,all_xs,all_bands[:,8,0]-fermi_level2,all_xs,all_bands[:,11,0]-fermi_level2,all_xs,all_bands[:,8,101]-fermi_level2)
#plt.plot(all_xs,all_bands[:,8,0]-fermi_level,all_xs,all_bands[:,10,0]-fermi_level)
#plt.plot(all_xs,all_bands[:,:,0],all_xs,all_bands[:,:,101])
plt.ylim((-.4,0.3))
# Out:
# (-0.4, 0.3)

# %%
plt.plot(all_xs,all_bands[:,4:15,0])
# Out:
# [<matplotlib.lines.Line2D at 0x107adc450>,
#  <matplotlib.lines.Line2D at 0x107adcb90>,
#  <matplotlib.lines.Line2D at 0x107adcd10>,
#  <matplotlib.lines.Line2D at 0x107adcf90>,
#  <matplotlib.lines.Line2D at 0x107acfb10>,
#  <matplotlib.lines.Line2D at 0x107acf110>,
#  <matplotlib.lines.Line2D at 0x107acfb90>,
#  <matplotlib.lines.Line2D at 0x10729abd0>,
#  <matplotlib.lines.Line2D at 0x107acfc50>,
#  <matplotlib.lines.Line2D at 0x107acfe50>,
#  <matplotlib.lines.Line2D at 0x107acf390>]
