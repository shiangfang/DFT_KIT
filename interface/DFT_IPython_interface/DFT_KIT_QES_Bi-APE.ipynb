# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import sys
import os

import xml.etree.ElementTree as ET
from DFT_KIT.core import job
from DFT_KIT.calculator import QESPRESSO
from DFT_KIT.core import physics

# %%
os.chdir('/Users/shiangfang/Shiang DrobBox/Dropbox/Physics Research/Tim Kaxiras Group/temp/new_biband/')

dft_job=job.job(False,False,False)
dft_calc=QESPRESSO.calculator_QESPRESSO(True,dft_job,None,None)
dft_job.sys_info['qes_prefix']='bi_sb_vca_alloy'
dft_calc.post_process()
# Out:
# DFT_KIT(ERROR):QESPRESSO: pp-no out file

# %%
plt.plot(physics.hartree*np.transpose(dft_calc.qes_vars['eigenvalues']))
#plt.ylim([0,10])
#plt.ylim([-90,-50])
# Out:
# [<matplotlib.lines.Line2D at 0x107acda50>,
#  <matplotlib.lines.Line2D at 0x107acdcd0>,
#  <matplotlib.lines.Line2D at 0x107acdf10>,
#  <matplotlib.lines.Line2D at 0x107ae4cd0>,
#  <matplotlib.lines.Line2D at 0x107ae4190>,
#  <matplotlib.lines.Line2D at 0x107ae4350>,
#  <matplotlib.lines.Line2D at 0x107ae4510>,
#  <matplotlib.lines.Line2D at 0x107b3d090>,
#  <matplotlib.lines.Line2D at 0x107ae4890>,
#  <matplotlib.lines.Line2D at 0x107ae4a50>,
#  <matplotlib.lines.Line2D at 0x107ae4c90>,
#  <matplotlib.lines.Line2D at 0x107ae4ed0>,
#  <matplotlib.lines.Line2D at 0x107af2110>,
#  <matplotlib.lines.Line2D at 0x107af22d0>,
#  <matplotlib.lines.Line2D at 0x107ae4710>,
#  <matplotlib.lines.Line2D at 0x107af2650>,
#  <matplotlib.lines.Line2D at 0x107af2810>,
#  <matplotlib.lines.Line2D at 0x107af29d0>,
#  <matplotlib.lines.Line2D at 0x107af2b90>,
#  <matplotlib.lines.Line2D at 0x107af2d50>,
#  <matplotlib.lines.Line2D at 0x107af2f10>,
#  <matplotlib.lines.Line2D at 0x107af24d0>,
#  <matplotlib.lines.Line2D at 0x107ad52d0>,
#  <matplotlib.lines.Line2D at 0x107ad5490>,
#  <matplotlib.lines.Line2D at 0x107ad5650>]
