# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import sys
import os

import xml.etree.ElementTree as ET

#sys.path.append('/Users/shiangfang/Shiang DrobBox/Dropbox/Physics Research/Tim Kaxiras Group/DFT VASP/DFT_tools')

# %%
name_prefix='../../temp/bi_convergence/'

all_totes=pickle.load(open(name_prefix+'ecutoff_conv','rb'))
all_es=np.linspace(15,60,46)
all_totes=np.array(all_totes)*13.6*1000

plt.plot(all_es,all_totes-np.mean(all_totes))
plt.ylim([-250,-220])
# Out:
# (-250, -220)

# %%
all_totes=pickle.load(open(name_prefix+'kgrid_conv','rb'))
all_ks=np.linspace(5,20,16)
all_totes=np.array(all_totes)*13.6*1000
plt.plot(all_ks,all_totes-np.mean(all_totes))

plt.ylim([-0,50])
# Out:
# (0, 50)
