# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import sys
import os

import xml.etree.ElementTree as ET

from DFT_KIT.core import physics
from DFT_KIT.interface import interface


#sys.path.append('/Users/shiangfang/Shiang DrobBox/Dropbox/Physics Research/Tim Kaxiras Group/DFT VASP/DFT_tools')

# %%
name_prefix='../../temp/bi_sb_alloy/final_data_oriTI'
all_xs=np.linspace(0,1,21)
all_ones=np.linspace(1,1,21)
f_=open(name_prefix,'rb')
fermi_level=pickle.load(f_)
fermi_level=np.array(fermi_level)*physics.hartree
all_bands=pickle.load(f_)
all_bands=np.array(all_bands)*physics.hartree
fermi_level2=pickle.load(f_)
fermi_level2=np.array(fermi_level2)*physics.hartree
f_.close()

plt.plot(np.transpose(all_bands[20]))
#plt.ylim([5,7])
# Out:
# [<matplotlib.lines.Line2D at 0x107cb6550>,
#  <matplotlib.lines.Line2D at 0x107cb67d0>,
#  <matplotlib.lines.Line2D at 0x107cb6a10>,
#  <matplotlib.lines.Line2D at 0x107cb6bd0>,
#  <matplotlib.lines.Line2D at 0x107cb6d90>,
#  <matplotlib.lines.Line2D at 0x107cb6f50>,
#  <matplotlib.lines.Line2D at 0x107cba150>,
#  <matplotlib.lines.Line2D at 0x107a035d0>,
#  <matplotlib.lines.Line2D at 0x107cba4d0>,
#  <matplotlib.lines.Line2D at 0x107cba690>,
#  <matplotlib.lines.Line2D at 0x107cba850>,
#  <matplotlib.lines.Line2D at 0x107cbaa10>,
#  <matplotlib.lines.Line2D at 0x107cbabd0>,
#  <matplotlib.lines.Line2D at 0x107cbad90>,
#  <matplotlib.lines.Line2D at 0x107cbaf50>,
#  <matplotlib.lines.Line2D at 0x107cbb150>,
#  <matplotlib.lines.Line2D at 0x107cbb310>,
#  <matplotlib.lines.Line2D at 0x107cbb4d0>]

# %%
plt.plot(all_xs,all_bands[:,7,101]-fermi_level,all_xs,all_bands[:,8,0]-fermi_level,all_xs,all_bands[:,11,0]-fermi_level,all_xs,all_bands[:,8,101]-fermi_level)
#plt.plot(all_xs,all_bands[:,8,0]-fermi_level,all_xs,all_bands[:,10,0]-fermi_level)
#plt.plot(all_xs,all_bands[:,:,0],all_xs,all_bands[:,:,101])
#plt.ylim((-1,0.3))
# Out:
# [<matplotlib.lines.Line2D at 0x107e88a90>,
#  <matplotlib.lines.Line2D at 0x107e88d10>,
#  <matplotlib.lines.Line2D at 0x107e8b410>,
#  <matplotlib.lines.Line2D at 0x107e8ba50>]

# %%
plt.plot(all_xs,all_bands[:,7,101]-fermi_level2,all_xs,all_bands[:,8,0]-fermi_level2,all_xs,all_bands[:,11,0]-fermi_level2,all_xs,all_bands[:,8,101]-fermi_level2)
#plt.plot(all_xs,all_bands[:,8,0]-fermi_level,all_xs,all_bands[:,10,0]-fermi_level)
#plt.plot(all_xs,all_bands[:,:,0],all_xs,all_bands[:,:,101])
plt.ylim((-.4,0.3))
# Out:
# (-0.4, 0.3)

# %%
plt.plot(all_xs,all_bands[:,4:15,0])
# Out:
# [<matplotlib.lines.Line2D at 0x10d460f50>,
#  <matplotlib.lines.Line2D at 0x10d465210>,
#  <matplotlib.lines.Line2D at 0x10d465450>,
#  <matplotlib.lines.Line2D at 0x10d465610>,
#  <matplotlib.lines.Line2D at 0x10d4657d0>,
#  <matplotlib.lines.Line2D at 0x10d465990>,
#  <matplotlib.lines.Line2D at 0x10d465b50>,
#  <matplotlib.lines.Line2D at 0x10d2ec610>,
#  <matplotlib.lines.Line2D at 0x10d465ed0>,
#  <matplotlib.lines.Line2D at 0x10d4680d0>,
#  <matplotlib.lines.Line2D at 0x10d468290>]

# %%
interface.matlab_save('dftdata',{'Fermi1':fermi_level,'Fermi2':fermi_level2,'Bands':all_bands})
