# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import sys
import os

import xml.etree.ElementTree as ET

from DFT_KIT.core import physics

#sys.path.append('/Users/shiangfang/Shiang DrobBox/Dropbox/Physics Research/Tim Kaxiras Group/DFT VASP/DFT_tools')

# %%
name_prefix='../../temp/bi_sb_alloy/final_data_ori'
all_xs=np.linspace(0,1,21)
all_ones=np.linspace(1,1,21)
f_=open(name_prefix,'rb')
fermi_level=pickle.load(f_)
fermi_level=np.array(fermi_level)*physics.hartree
all_bands=pickle.load(f_)
all_bands=np.array(all_bands)*physics.hartree
f_.close()
print(all_bands[5,1,1])

plt.plot(np.transpose(all_bands[0]))
plt.ylim([7,8])
# Out:
# -4.77171975412
# (7, 8)

# %%
#plt.plot(all_xs,all_bands[:,8,0]-fermi_level,all_xs,all_bands[:,11,0]-fermi_level,all_xs,all_bands[:,8,101]-fermi_level)
#plt.plot(all_xs,all_bands[:,8,0]-fermi_level,all_xs,all_bands[:,10,0]-fermi_level)
plt.plot(all_xs,all_bands[:,8,0],all_xs,all_bands[:,11,0],all_xs,all_bands[:,8,101])
# Out:
# [<matplotlib.lines.Line2D at 0x10773fcd0>,
#  <matplotlib.lines.Line2D at 0x10773ff50>,
#  <matplotlib.lines.Line2D at 0x1078c1650>]

# %%
plt.plot(all_xs,all_bands[:,4:15,0])
# Out:
# [<matplotlib.lines.Line2D at 0x1076e2650>,
#  <matplotlib.lines.Line2D at 0x1076e28d0>,
#  <matplotlib.lines.Line2D at 0x1076e2b10>,
#  <matplotlib.lines.Line2D at 0x1076e2cd0>,
#  <matplotlib.lines.Line2D at 0x1076e2e90>,
#  <matplotlib.lines.Line2D at 0x1076e6090>,
#  <matplotlib.lines.Line2D at 0x1076e6250>,
#  <matplotlib.lines.Line2D at 0x1076cacd0>,
#  <matplotlib.lines.Line2D at 0x1076e65d0>,
#  <matplotlib.lines.Line2D at 0x1076e6790>,
#  <matplotlib.lines.Line2D at 0x1076e6950>]
